# %%
a = "*"                                  #Nested loop (star pattern,triangle no. pattern, r,ri,rit,ritu as per if condition)
row = 2
col = 3
for i in range(row):
  for j in range(col):
    # print(f"{i},{j}\t", end="")
    print(f"{a}", end="")
  print()
# Out:
# ***
# ***

# %%
0,0       0,1     0,2       0,3       0,4
1,0       1,1     1,2       1,3       1,4
2,0       2,1     2,2       2,3       2,4
3,0       3,1     3,2       3,3       3,4
4,0       4,1     4,2       4,3       4,4
